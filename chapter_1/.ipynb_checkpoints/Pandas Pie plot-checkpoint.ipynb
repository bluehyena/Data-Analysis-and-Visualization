# %% [markdown]
# # Pie plot
# * Seaborn 에서는 파이차트를 지원하지 않는다.
#     - 면적에 따라서 오해의 소지가 있을 수 있어서 데이터를 명확하게 표현할 수 없다.
# * Pandas 에서는 Pie plot 을 사용할 수 있다.

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl

# %matplotlib inline

mpl.rcParams['axes.unicode_minus'] = False

# %%
series = pd.Series(3*np.random.rand(4), index = ['a','b','c','d'], name='series')
series
# Out:
# a    0.816070
# b    1.892637
# c    0.560281
# d    2.258774
# Name: series, dtype: float64

# %%
series.plot.pie()
# Out:
# <AxesSubplot:ylabel='series'>

# %%
series.plot.pie(figsize=(6,6))
# Out:
# <AxesSubplot:ylabel='series'>

# %%
df = pd.DataFrame({'mass' : [0.330, 4.87, 5.97], 
                   'radius': [2439.7, 6051.8, 6378.1]},
                 index = ['Mercury','Venus','Earth'])
plot = df.plot.pie(y='mass', figsize=(5,5))

# %%
plot = df.plot.pie(subplots=True, figsize=(10,5))

# %%
series.plot.pie(labels=['AA', 'BB','CC','DD'], 
                colors=['r','g','b','c'],
                autopct='%.2f', fontsize=20, figsize=(6,6))
# Out:
# <AxesSubplot:ylabel='series'>
