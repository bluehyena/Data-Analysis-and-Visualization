# %%
import pandas as pd
import numpy as np
# %matplotlib inline


#https://pandas.pydata.org/pandas-docs/stable/user_guide/computation.html
#https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.expanding.html
#https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.rolling.html

# %%
s = pd.Series(np.random.randn(1000), 
              index=pd.date_range('1/1/2015', periods=1000))
s
# Out:
# 2015-01-01    1.796927
# 2015-01-02   -3.091479
# 2015-01-03   -1.862212
# 2015-01-04   -1.136146
# 2015-01-05   -1.695821
#                 ...
# 2017-09-22    1.257301
# 2017-09-23    1.771380
# 2017-09-24    0.037799
# 2017-09-25    0.042681
# 2017-09-26   -1.127321
# Freq: D, Length: 1000, dtype: float64

# %%
s.plot()
# Out:
# <AxesSubplot:>

# %%
s = s.cumsum()

# %%
s.plot()
# Out:
# <AxesSubplot:>

# %%
r = s.rolling(window=60)
r
# Out:
# Rolling [window=60,center=False,axis=0]

# %%
r.mean()
# Out:
# 2015-01-01         NaN
# 2015-01-02         NaN
# 2015-01-03         NaN
# 2015-01-04         NaN
# 2015-01-05         NaN
#                 ...
# 2017-09-22   -1.027551
# 2017-09-23   -0.992302
# 2017-09-24   -0.953022
# 2017-09-25   -0.938326
# 2017-09-26   -0.918643
# Freq: D, Length: 1000, dtype: float64

# %%
s.plot(style='k--')
# Out:
# <AxesSubplot:>

# %%
r.mean().plot(style='k')
# Out:
# <AxesSubplot:>

# %%
s.plot(style='k--')
r.mean().plot(style='k')
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.randn(1000, 4),
                 index=pd.date_range('1/1/2015', periods=1000),
                 columns=['A','B','C','D'])
df
# Out:
#                    A         B         C         D
# 2015-01-01  0.066899  0.049618  1.620119 -0.565976
# 2015-01-02  1.409050  1.391972 -1.653590 -0.480151
# 2015-01-03 -0.398308  0.317661  1.286162 -0.352545
# 2015-01-04 -0.154674  0.685995 -0.948794  0.543181
# 2015-01-05  1.321851 -0.459559  0.462312 -0.762658
# ...              ...       ...       ...       ...
# 2017-09-22  0.127762 -0.099131 -0.381010  0.328458
# 2017-09-23  0.611137  0.669459 -0.175868  0.400466
# 2017-09-24  1.305460  0.476729 -1.024921  0.974239
# 2017-09-25 -1.657936  1.130328  0.142569  1.012650
# 2017-09-26 -1.115102 -2.792904  1.153463 -0.917559
#
# [1000 rows x 4 columns]

# %%
df = df.cumsum()
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.rolling(window=60).sum().plot(subplots=True)
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#       dtype=object)

# %%
df.rolling(window=len(df), min_periods=1).mean().plot()
# Out:
# <AxesSubplot:>

# %%
df.expanding(min_periods=1).mean().plot()
# Out:
# <AxesSubplot:>

# %%
df.expanding?

# %%
dfe = pd.DataFrame({"B": [0, 1, 2, np.nan, 4]})

# %%
dfe
# Out:
#      B
# 0  0.0
# 1  1.0
# 2  2.0
# 3  NaN
# 4  4.0

# %%
dfe.expanding(2).sum()
# Out:
#      B
# 0  NaN
# 1  1.0
# 2  3.0
# 3  3.0
# 4  7.0

# %%
dfe.expanding(2).sum().plot()
# Out:
# <AxesSubplot:>
