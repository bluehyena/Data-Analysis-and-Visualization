# %% [markdown]
# # scatter plot
# * 산점도

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %matplotlib inline

mpl.rcParams['axes.unicode_minus'] = False

# %%
df = pd.DataFrame(np.random.rand(50, 4), columns=['a','b','c','d'])
df
# Out:
#            a         b         c         d
# 0   0.333834  0.736619  0.214628  0.847996
# 1   0.929231  0.365040  0.869703  0.415625
# 2   0.282828  0.304261  0.950030  0.536325
# 3   0.017281  0.958960  0.380872  0.909002
# 4   0.612493  0.376261  0.190178  0.093470
# 5   0.033183  0.859544  0.277185  0.286130
# 6   0.548520  0.433237  0.148462  0.716502
# 7   0.663149  0.453250  0.999408  0.734083
# 8   0.865071  0.437848  0.179280  0.904755
# 9   0.436474  0.216452  0.759232  0.322797
# 10  0.229738  0.234084  0.152245  0.573117
# 11  0.918553  0.828769  0.460096  0.740170
# 12  0.973370  0.528208  0.216056  0.192677
# 13  0.707746  0.892370  0.299086  0.503601
# 14  0.496491  0.423835  0.311456  0.866015
# 15  0.836552  0.007126  0.963264  0.335502
# 16  0.160066  0.137072  0.779294  0.971621
# 17  0.060834  0.840889  0.410048  0.336178
# 18  0.694250  0.750241  0.694511  0.387140
# 19  0.984087  0.617603  0.362806  0.914492
# 20  0.284531  0.176516  0.847950  0.196375
# 21  0.235567  0.368299  0.876137  0.579070
# 22  0.376697  0.022660  0.799644  0.849690
# 23  0.053328  0.704980  0.267221  0.270602
# 24  0.364449  0.252773  0.537073  0.929967
# 25  0.617688  0.931078  0.557499  0.899072
# 26  0.630388  0.110697  0.672976  0.220998
# 27  0.183173  0.357848  0.028933  0.871158
# 28  0.036164  0.570575  0.777310  0.657642
# 29  0.918686  0.104256  0.072631  0.842790
# 30  0.600863  0.333180  0.658064  0.334707
# 31  0.783250  0.334608  0.866435  0.945837
# 32  0.521377  0.679067  0.228004  0.408784
# 33  0.539327  0.374517  0.041211  0.156199
# 34  0.925486  0.716330  0.242062  0.274625
# 35  0.809067  0.031682  0.442459  0.085232
# 36  0.888040  0.446761  0.006629  0.990051
# 37  0.242373  0.623440  0.328599  0.239687
# 38  0.794670  0.656125  0.356417  0.234121
# 39  0.005922  0.558020  0.524479  0.392934
# 40  0.612733  0.963093  0.797656  0.882345
# 41  0.953735  0.947156  0.547100  0.643843
# 42  0.779830  0.267678  0.126284  0.798663
# 43  0.854734  0.857485  0.389497  0.360479
# 44  0.647253  0.081230  0.188639  0.477144
# 45  0.364496  0.817460  0.029441  0.692867
# 46  0.842838  0.419834  0.747015  0.810490
# 47  0.491066  0.137192  0.511396  0.060526
# 48  0.876325  0.349397  0.290097  0.353279
# 49  0.588304  0.576211  0.611648  0.429904

# %%
df.plot.scatter(x='a', y='b', s= 10, grid = True)
# scatter plot 은 x와 y를 반드시 지정해 주어야함
# s == 점의 크기
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
ax = df.plot.scatter(x='a', y='b', color='DarkBlue', label='Group 1')
df.plot.scatter(x='c', y='d', color='DarkGreen', label='Group 2', ax=ax)
# Out:
# <AxesSubplot:xlabel='c', ylabel='d'>

# %%
df.plot.scatter(x='a', y='b', c='c', s= 10, grid = True)
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df.plot.scatter(x='a', y='b', s=df['c'] * 200)
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>
