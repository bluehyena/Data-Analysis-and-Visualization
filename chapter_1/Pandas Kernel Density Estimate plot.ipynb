# %% [markdown]
# # Kernel Density Estimate plot
#
# * Kernel Density Estimation
# * 통계에서 커널 밀도 측정 (KDE)는 임의 변수의 확률 밀도 함수(PDF)를 추정하는 비모수적 방법이다. 이 함수는 가우스 커널을 사용하며 자동 대역폭 결정을 포함한다.
# * 비모수 통계 : 비모수 통계는 통계학에서 모수에 대한 가정을 전제로 하지 않고 모집단의 형태에 관계없이 주어진 데이터에서 직접 확률을 계산하여 통계학적 검정을 하는 분석법이다.
# * 커널 밀도 추정치는 히스토그램과 밀접한 관련이 있지만 적절한 커널을 사용하여 매끄럽고 연속성과 같은 속성을 부여할 수 있다.
# * 커널 함수는 원점을 중심으로 대칭이며 적분값이 1인 함수다.
#
# ## Probability Density Function
# * 확률론에서 확률 밀도 함수(probability density function 약자 pdf)는 확률 변수의 분포를 나타내는 함수로 적분값이 1이 된다.
# * 확률변수란? : 확률론에서, 확률 변수(random variable)는 확률적인 과정에 따라 값이 결정되는 변수를 말한다. 이는 엄밀히 말하자면 시행 결과에 대한 집합인 확률 공간에서 가측 공간으로 가는 가측 함수를 의미한다.
#
# ## Normal Distribution
# * 정규분포(Normal Distribution)는 수집된 자료의 분포를 근사하는 데에 자주 사용되며, 이것은 중심극한정리에 의하여 독립적인 확률변수들의 평균은 정규분포에 가까워지는 성질이 있기 때문이다.
#
# ## 공식문서
# * https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html#density-plot

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# %matplotlib inline

mpl.rcParams['axes.unicode_minus'] = False

# %%
ser = pd.Series(np.random.randn(1000))

# %%
ser
# Out:
# 0     -1.454644
# 1      0.133481
# 2      0.512267
# 3      0.914479
# 4      0.483520
#          ...
# 995   -2.037712
# 996    0.246437
# 997    0.498800
# 998   -0.126475
# 999   -1.044247
# Length: 1000, dtype: float64

# %%
ser.plot()
# Out:
# <AxesSubplot:>

# %%
ser.plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
ser.plot.kde() # 같은 그래프
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
ser.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>
