# %%
import pandas as pd
import numpy as np

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# 한글폰트 사용시 그래프에서 마이너스 폰트가 깨지는 문제에 대한 대처
mpl.rcParams['axes.unicode_minus'] = False

# %%
df = pd.DataFrame()

# %%
df.plot?

# %% [markdown]
# ## kind : str
#    ### The kind of plot to produce:
#
#     - 'line' : line plot (default)
#     - 'bar' : vertical bar plot
#     - 'barh' : horizontal bar plot
#     - 'hist' : histogram
#     - 'box' : boxplot
#     - 'kde' : Kernel Density Estimation plot
#     - 'density' : same as 'kde'
#     - 'area' : area plot
#     - 'pie' : pie plot
#     - 'scatter' : scatter plot
#     - 'hexbin' : hexbin plot.

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))

# %%
ts
# Out:
# 2000-01-01   -0.124729
# 2000-01-02   -0.190099
# 2000-01-03    0.829010
# 2000-01-04   -1.123643
# 2000-01-05   -0.048366
#                 ...
# 2002-09-22    0.969327
# 2002-09-23   -0.163296
# 2002-09-24    1.690901
# 2002-09-25   -0.246510
# 2002-09-26   -0.545124
# Freq: D, Length: 1000, dtype: float64

# %%
ts.plot()
# Out:
# <AxesSubplot:>

# %%
ts = ts.cumsum() # 누적합
ts.plot()
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.randn(1000,4), index=ts.index, columns=list('ABCD'))

# %%
df
# Out:
#                    A         B         C         D
# 2000-01-01  0.098622  1.437161 -0.400353  0.749499
# 2000-01-02  0.899329  0.329795  2.045937  0.298297
# 2000-01-03 -1.010276 -2.730142 -0.244618  0.692693
# 2000-01-04 -0.480587  1.331371 -0.784833 -0.052890
# 2000-01-05 -2.223377  0.546565 -0.226594  0.569140
# ...              ...       ...       ...       ...
# 2002-09-22  0.173398  0.789041  0.504189 -1.640842
# 2002-09-23  0.314680  0.115802  0.605690 -0.126298
# 2002-09-24 -0.174157 -1.022878 -0.148774 -0.125522
# 2002-09-25 -1.550179 -1.002550 -1.123500  0.033153
# 2002-09-26 -0.242310  0.359827 -0.000975 -0.688554
#
# [1000 rows x 4 columns]

# %%
df.shape
# Out:
# (1000, 4)

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df = df.cumsum()

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df3 = pd.DataFrame(np.random.randn(1000, 2), columns=['B','C']).cumsum()

# %%
df3.head()
# Out:
#           B         C
# 0  0.851491 -0.395114
# 1  0.945017 -0.343926
# 2 -0.497935  0.077429
# 3 -0.366570  0.584533
# 4  0.396079  1.497634

# %%
df3['A'] = pd.Series(list(range(len(df))))

# %%
df3.head()
# Out:
#           B         C  A
# 0  0.851491 -0.395114  0
# 1  0.945017 -0.343926  1
# 2 -0.497935  0.077429  2
# 3 -0.366570  0.584533  3
# 4  0.396079  1.497634  4

# %%
df3.plot(x='A', y='B')
# Out:
# <AxesSubplot:xlabel='A'>
